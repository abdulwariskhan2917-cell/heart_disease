# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("heart.csv")
print(data.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print(data)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
print(data.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
print(data.tail())
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0

# %%
print(data.shape)
# Out:
# (303, 14)

# %%
print(data.columns)
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB
# None

# %%
print(data.describe())
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %%
# renaming the columns
data.rename(columns={
        "age": "Age",
        "sex" : "Gender",
        "cp" : "ChestPainType",
        "trestbps" : "RestingBP",
        "chol" : "Cholesterol",
        "fbs" : "FastingBS",
        "restecg" : "RestingECG",
        "thalach" : "MaxHR",
        "exang" : "ExerciseAngina",
        "oldpeak" : "ST_Depression",
        "slope" : "ST_Slope",
        "ca" : "MajorVessels",
        "thal" : "Thalassemia",
        "target" : "HeartDisease"
    }, inplace=True)
print("Updated dataset:",data.head())
data.columns
# Out:
# Updated dataset:    Age  Gender  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   63       1              3        145          233          1           0
# 1   37       1              2        130          250          0           1
# 2   41       0              1        130          204          0           0
# 3   56       1              1        120          236          0           1
# 4   57       0              0        120          354          0           1
#
#    MaxHR  ExerciseAngina  ST_Depression  ST_Slope  MajorVessels  Thalassemia  \
# 0    150               0            2.3         0             0            1
# 1    187               0            3.5         0             0            2
# 2    172               0            1.4         2             0            2
# 3    178               0            0.8         2             0            2
# 4    163               1            0.6         2             0            2
#
#    HeartDisease
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'ChestPainType', 'RestingBP', 'Cholesterol',
#        'FastingBS', 'RestingECG', 'MaxHR', 'ExerciseAngina', 'ST_Depression',
#        'ST_Slope', 'MajorVessels', 'Thalassemia', 'HeartDisease'],
#       dtype='str')

# %%
data.min()
# Out:
# Age                29.0
# Gender              0.0
# ChestPainType       0.0
# RestingBP          94.0
# Cholesterol       126.0
# FastingBS           0.0
# RestingECG          0.0
# MaxHR              71.0
# ExerciseAngina      0.0
# ST_Depression       0.0
# ST_Slope            0.0
# MajorVessels        0.0
# Thalassemia         0.0
# HeartDisease        0.0
# dtype: float64

# %%
data.max()
# Out:
# Age                77.0
# Gender              1.0
# ChestPainType       3.0
# RestingBP         200.0
# Cholesterol       564.0
# FastingBS           1.0
# RestingECG          2.0
# MaxHR             202.0
# ExerciseAngina      1.0
# ST_Depression       6.2
# ST_Slope            2.0
# MajorVessels        4.0
# Thalassemia         3.0
# HeartDisease        1.0
# dtype: float64

# %%
#data cleaning
data.isnull()
# Out:
#        Age  Gender  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    False   False          False      False        False      False
# 1    False   False          False      False        False      False
# 2    False   False          False      False        False      False
# 3    False   False          False      False        False      False
# 4    False   False          False      False        False      False
# ..     ...     ...            ...        ...          ...        ...
# 298  False   False          False      False        False      False
# 299  False   False          False      False        False      False
# 300  False   False          False      False        False      False
# 301  False   False          False      False        False      False
# 302  False   False          False      False        False      False
#
#      RestingECG  MaxHR  ExerciseAngina  ST_Depression  ST_Slope  MajorVessels  \
# ...

# %%
data.isnull().sum()
# Out:
# Age               0
# Gender            0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# ST_Depression     0
# ST_Slope          0
# MajorVessels      0
# Thalassemia       0
# HeartDisease      0
# dtype: int64

# %%
# removing duplicates data / finding duplicates data
duplicate = data.duplicated().sum()
print("total duplicates rows:", duplicate)
# Out:
# total duplicates rows: 1

# %%
# display duplicate row
duplicate_row = data[data.duplicated()]
duplicate_row
# Out:
#      Age  Gender  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 164   38       1              2        138          175          0
#
#      RestingECG  MaxHR  ExerciseAngina  ST_Depression  ST_Slope  MajorVessels  \
# 164           1    173               0            0.0         2             4
#
#      Thalassemia  HeartDisease
# 164            2             1

# %%
# keep_false return all as True are duplicates (both copies)
duplicate_all = data[data.duplicated(keep=False)]
duplicate_all
# Out:
#      Age  Gender  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 163   38       1              2        138          175          0
# 164   38       1              2        138          175          0
#
#      RestingECG  MaxHR  ExerciseAngina  ST_Depression  ST_Slope  MajorVessels  \
# 163           1    173               0            0.0         2             4
# 164           1    173               0            0.0         2             4
#
#      Thalassemia  HeartDisease
# 163            2             1
# 164            2             1

# %%
data = data.drop_duplicates()
print("shape of aur dataset after removing duplicates rows")
print(data.shape)
# Out:
# shape of aur dataset after removing duplicates rows
# (302, 14)

# %%
print("Before:", len(data)+1)
data = data.drop_duplicates()
print("After:", len(data))
# Out:
# Before: 303
# After: 302

# %%
import seaborn as sns

#data outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=data[["Age","RestingBP","Cholesterol","MaxHR","ST_Depression"]])
plt.title("Box plot of numerical features")
plt.show()

# %%
# handling outlier
def cap_outliers(data,column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    
    data[column] = np.where(data[column] > upper_bound, upper_bound,
                             np.where(data[column] < lower_bound, lower_bound, data[column]))

# apply to columns
cap_outliers(data, "Age")
cap_outliers(data, "RestingBP")
cap_outliers(data, "Cholesterol")
cap_outliers(data, "MaxHR")
cap_outliers(data, "ST Depression")

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data[["Age","RestingBP","Cholesterol","MaxHR","ST_Depression"]])
plt.title("Box plot of numerical features")
plt.show()

# %%
# correlation matrix on numeric columns onl
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation heatmap after cleaning")
plt.show()

# %%
print("Final dataset shape:" ,data.shape)
print("Any  missing values:")
print(data.isnull().sum())
data.head()
# Out:
# Final dataset shape: (302, 14)
# Any  missing values:
# Age               0
# Gender            0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# ST_Depression     0
# ST_Slope          0
# MajorVessels      0
# Thalassemia       0
# HeartDisease      0
# dtype: int64
#    Age  Gender  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   63       1              3        145          233          1           0
# 1   37       1              2        130          250          0           1
# 2   41       0              1        130          204          0           0
# 3   56       1              1        120          236          0           1
# 4   57       0              0        120          354          0           1
#
#    MaxHR  ExerciseAngina  ST_Depression  ST_Slope  MajorVessels  Thalassemia  \
# ...

# %%
# data preprocessing
# separating features and target variable
# encoding categorical variables
# scaling numerical features
# splitting the data into training and testing sets

# %%
# separating features and target variable
X = data.drop("HeartDisease", axis=1)
y = data["HeartDisease"]
print("Features  matrix shape:", X.shape)
# Out:
# Features  matrix shape: (302, 13)

# %%
# encoding categorical data
categorical_cols = ["Gender", "ChestPainType","FastingBS", "RestingECG", "ExerciseAngina", "ST_Slope", "MajorVessels", "Thalassemia"]
numeric_cols = ["Age", "RestingBP", "Cholesterol", "MaxHR", "ST_Depression"]

print("categorical_columns:", categorical_cols)
print("numeric_columns:", numeric_cols)
# Out:
# categorical_columns: ['Gender', 'ChestPainType', 'FastingBS', 'RestingECG', 'ExerciseAngina', 'ST_Slope', 'MajorVessels', 'Thalassemia']
# numeric_columns: ['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'ST_Depression']

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# encoding categorical variables
X_encoder = pd.get_dummies(data,columns=categorical_cols, drop_first=True)
print("Shape after encoding:", X_encoder.shape)
X_encoder.head()
# Out:
# Shape after encoding: (302, 23)
#    Age  RestingBP  Cholesterol  MaxHR  ST_Depression  HeartDisease  Gender_1  \
# 0   63        145          233    150            2.3             1      True
# 1   37        130          250    187            3.5             1      True
# 2   41        130          204    172            1.4             1     False
# 3   56        120          236    178            0.8             1      True
# 4   57        120          354    163            0.6             1     False
#
#    ChestPainType_1  ChestPainType_2  ChestPainType_3  ...  ExerciseAngina_1  \
# 0            False            False             True  ...             False
# 1            False             True            False  ...             False
# 2             True            False            False  ...             False
# 3             True            False            False  ...             False
# 4            False            False            False  ...              True
#
# ...

# %%
# feature scalling 
scaler = StandardScaler()
X_encoder[numeric_cols] = scaler.fit_transform(X_encoder[numeric_cols])
print("scaled numeric feature :")
print(X_encoder[numeric_cols])
# Out:
# scaled numeric feature :
#           Age  RestingBP  Cholesterol     MaxHR  ST_Depression
# 0    0.949794   0.764066    -0.261285  0.018826       1.084022
# 1   -1.928548  -0.091401     0.067741  1.636979       2.118926
# 2   -1.485726  -0.091401    -0.822564  0.980971       0.307844
# 3    0.174856  -0.661712    -0.203222  1.243374      -0.209608
# 4    0.285561  -0.661712     2.080602  0.587366      -0.382092
# ..        ...        ...          ...       ...            ...
# 298  0.285561   0.478910    -0.106449 -1.161988      -0.727060
# 299 -1.042904  -1.232023     0.338703 -0.768384       0.135360
# 300  1.503322   0.707035    -1.035462 -0.374779       2.032684
# 301  0.285561  -0.091401    -2.235438 -1.511859       0.135360
# 302  0.285561  -0.091401    -0.203222  1.068439      -0.899544
#
# [302 rows x 5 columns]

# %%
# splitting data into training and testing
X_train, X_test, y_train, y_test = train_test_split(
    X_encoder,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)
print("training data shape:", X_train.shape)
print("testing data shape:", X_test.shape)
# Out:
# training data shape: (241, 23)
# testing data shape: (61, 23)

# %%
# Model training and evaluation
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# logistic regression

log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)

y_pred_lr = log_reg.predict(X_test)
cm_lr = confusion_matrix(y_test, y_pred_lr)

# %%
plt.figure(figsize=(5, 4))
sns.heatmap(cm_lr, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
# Random Forest Classifier
rf_clf = RandomForestClassifier(n_estimators=200, random_state=42)
rf_clf.fit(X_train, y_train)
y_pred_rf = rf_clf.predict(X_test)

accuaracy_rf = accuracy_score(y_test, y_pred_rf)
cm_rf = confusion_matrix(y_test, y_pred_rf)

print("\n Random Forest Accuracy: ", round(accuaracy_rf* 100,2),"%")
print("\n Classification Report:\n", classification_report(y_test, y_pred_rf))

# Confusion Matrix Visualization
plt.figure(figsize=(5, 4))
sns.heatmap(cm_rf, annot=True, fmt="d", cmap="Blues")
plt.title("Confusion Matrix - Random Forest")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
#  Random Forest Accuracy:  100.0 %
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        28
#            1       1.00      1.00      1.00        33
#
#     accuracy                           1.00        61
#    macro avg       1.00      1.00      1.00        61
# weighted avg       1.00      1.00      1.00        61

# %%
# comparing model
accuaracy_lr = accuracy_score(y_test, y_pred_lr)
results = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest"],
    "Accuracy": [accuaracy_lr,accuaracy_rf]
})
print("model comparison")
print(results)
# Out:
# model comparison
#                  Model  Accuracy
# 0  Logistic Regression       1.0
# 1        Random Forest       1.0

# %%
# comparing model
accuaracy_lr = accuracy_score(y_test, y_pred_lr)
results = pd.DataFrame({
    "Model": ["Logistic Regression", "Random Forest"],
    "Accuracy": [accuaracy_lr,accuaracy_rf]
})
print("model comparison")
print(results)


plt.figure(figsize=(6, 4))
sns.barplot(x="Model", y="Accuracy", data=results,palette="viridis")
plt.title("Model Accuracy Comparison")
plt.show()
# Out:
# model comparison
#                  Model  Accuracy
# 0  Logistic Regression       1.0
# 1        Random Forest       1.0
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11548\3527562868.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Model", y="Accuracy", data=results,palette="viridis")

# %%
# saving the model
import pickle
with open("heart_disease_model.pkl", "wb") as file:
    pickle.dump((rf_clf,scaler), file)
     

print("Model saved successfully")
# Out:
# Model saved successfully

# %%
import streamlit as st
Sex = st.selectbox("Sex", ["M", "F"])

Chest_pain_type = st.selectbox(
    "Chest Pain Type",
    ["TA", "ATA", "NAP", "ASY"]
)

RestingECG = st.selectbox(
    "Resting ECG Result",
    ["Normal", "ST", "LVH"]
)

ExerciseAngina = st.selectbox(
    "Exercise Induced Angina",
    ["N", "Y"]
)

ST_Slope = st.selectbox(
    "ST Slope",
    ["Up", "Flat", "Down"]
)

Sex = 1 if Sex == "M" else 0
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 import streamlit as st
#       2 Sex = st.selectbox("Sex", ["M", "F"])
#       3
#       4 Chest_pain_type = st.selectbox(
#
# ModuleNotFoundError: No module named 'streamlit'

# %%
# Numbers ko text mein convert karne ke liye (Mapping)
cp_map = {0: 'TA', 1: 'ATA', 2: 'NAP', 3: 'ASY'}
ecg_map = {0: 'Normal', 1: 'ST', 2: 'LVH'}
slope_map = {0: 'Up', 1: 'Flat', 2: 'Down'}
